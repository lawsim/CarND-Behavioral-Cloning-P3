# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Analysis
# I'd like to find the distribution of the steering angles first

# %%
df = pd.read_csv('./data/driving_log.csv', 
                 header=None, 
                 names=['center','left','right','steering_angle','throttle','brake','speed'])
df.head(100)
# Out:
#                                                center  \
# 0   C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 1   C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 2   C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 3   C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 4   C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 5   C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 6   C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 7   C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 8   C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 9   C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 10  C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 11  C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 12  C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 13  C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 14  C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# 15  C:\projects\nd103\CarND-Behavioral-Cloning-P3\...
# ...

# %%
steering_angles = np.array(df['steering_angle'])

# %%
plt.plot(steering_angles[500:1500])

# %%
df.describe()
# Out:
#        steering_angle     throttle        brake         speed
# count     6426.000000  6426.000000  6426.000000  6.426000e+03
# mean         0.003502     0.536102     0.008733  2.433801e+01
# std          0.270359     0.403509     0.069994  6.751840e+00
# min         -1.000000     0.000000     0.000000  8.340401e-07
# 25%         -0.093985     0.116098     0.000000  1.897713e+01
# 50%          0.000000     0.400000     0.000000  2.799786e+01
# 75%          0.097744     1.000000     0.000000  3.003867e+01
# max          1.000000     1.000000     1.000000  3.048579e+01

# %%
df.hist(column=['steering_angle'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E5C01A5E48>]], dtype=object)
